# %%
#Ai Final Project
#Team:
#Jose Esteban Guzman Alvarez ID: 101028810
#Serhii Kravtsov ID: 101132205
#
import numpy as np
import pandas as pd
from sklearn import tree 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Data/heart.csv")
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
mydf=data.rename(columns={"age":"Age",
                         "sex": "Sex",
                         "cp":"Chest pain type ",
                         "trestbps":"Resting blood pressure ",
                         "chol":"Serum cholestoral",
                         "fbs":"Fasting blood sugar > 120 mg/dl",
                         "restecg":"Resting electrocardiographic results",
                         "thalach":"Maximum heart rate achieved",
                         "exang":"Exercise induced angina",
                         "oldpeak":"ST depression induced by exercise relative to rest",
                         "slope":"The slope of the peak exercise ST segment",
                         "ca":"Number of major vessels (0-3) colored by flourosopy",
                         "thal":"3 = normal; 6 = fixed defect 7= reversable defect ",
                         "target":"target"})

# %%
mydf.head()
# Out:
#    Age  Sex  Chest pain type   Resting blood pressure   Serum cholestoral  \
# 0   63    1                 3                      145                233
# 1   37    1                 2                      130                250
# 2   41    0                 1                      130                204
# 3   56    1                 1                      120                236
# 4   57    0                 0                      120                354
#
#    Fasting blood sugar > 120 mg/dl  Resting electrocardiographic results  \
# 0                                1                                     0
# 1                                0                                     1
# 2                                0                                     0
# 3                                0                                     1
# 4                                0                                     1
#
#    Maximum heart rate achieved  Exercise induced angina  \
# ...

# %%
mydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# Age                                                    303 non-null int64
# Sex                                                    303 non-null int64
# Chest pain type                                        303 non-null int64
# Resting blood pressure                                 303 non-null int64
# Serum cholestoral                                      303 non-null int64
# Fasting blood sugar > 120 mg/dl                        303 non-null int64
# Resting electrocardiographic results                   303 non-null int64
# Maximum heart rate achieved                            303 non-null int64
# Exercise induced angina                                303 non-null int64
# ST depression induced by exercise relative to rest     303 non-null float64
# The slope of the peak exercise ST segment              303 non-null int64
# ...

# %%
maxHR = np.array(mydf['Maximum heart rate achieved'])
print(maxHR)
# Out:
# [150 187 172 178 163 148 153 173 162 174 160 139 171 144 162 158 172 114
#  171 151 161 179 178 137 178 162 157 123 157 152 168 140 188 152 125 160
#  170 165 148 151 142 180 148 143 182 172 180 156 115 160 149 151 146 175
#  172 158 186 185 174 159 130 156 190 132 165 182 143 175 170 163 147 154
#  202 186 165 161 166 164 184 154 179 170 160 178 122 160 151 156 158 122
#  175 168 169 159 138 111 157 147 162 173 178 145 179 194 163 115 131 152
#  162 159 154 173 133 161 155 170 168 162 172 152 122 182 172 167 179 192
#  143 172 169 121 163 162 162 153 163 163  96 140 126 105 157 181 173 142
#  116 143 149 171 169 150 138 125 155 152 152 131 179 174 144 163 169 166
#  182 173 173 108 129 160 147 155 142 168 160 173 132 114 160 158 120 112
#  132 114 169 165 128 153 144 109 163 158 142 131 113 142 155 140 147 163
#   99 158 177 141 111 150 145 161 142 157 139 162 150 140 140 146 144 136
#   97 132 127 150 154 111 174 133 126 125 103 130 159 131 152 124 145  96
# ...

# %%
mydf.dtypes
# Out:
# Age                                                      int64
# Sex                                                      int64
# Chest pain type                                          int64
# Resting blood pressure                                   int64
# Serum cholestoral                                        int64
# Fasting blood sugar > 120 mg/dl                          int64
# Resting electrocardiographic results                     int64
# Maximum heart rate achieved                              int64
# Exercise induced angina                                  int64
# ST depression induced by exercise relative to rest     float64
# The slope of the peak exercise ST segment                int64
# Number of major vessels (0-3) colored by flourosopy      int64
# 3 = normal; 6 = fixed defect 7= reversable defect        int64
# target                                                   int64
# dtype: object

# %%
maxHR.size
# Out:
# 303

# %%
print("Average:            ", np.average(maxHR))
print("Standard deviation: ", np.std(maxHR))
print("Minimum:            ", np.min(maxHR))
print("Maximum:            ", np.max(maxHR))
print("25th percentile:    ", np.percentile(maxHR, 25))
print("Median:             ", np.median(maxHR))
print("75th percentile:    ", np.percentile(maxHR, 75))
# Out:
# Average:             149.64686468646866
# Standard deviation:  22.86733258188924
# Minimum:             71
# Maximum:             202
# 25th percentile:     133.5
# Median:              153.0
# 75th percentile:     166.0

# %%
import seaborn as sns
import matplotlib

sns.set_style("white")
sns.distplot(maxHR, norm_hist=True)
plt.title('Overall Max Heart Rate Distribution')
plt.xlabel('Heart Rate')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
# make age group for xlabel, max heart rates for ylabel, compare numbers of maxHR by gender and age groups
mydf.describe()
# Out:
#               Age         Sex  Chest pain type   Resting blood pressure   \
# count  303.000000  303.000000        303.000000               303.000000
# mean    54.366337    0.683168          0.966997               131.623762
# std      9.082101    0.466011          1.032052                17.538143
# min     29.000000    0.000000          0.000000                94.000000
# 25%     47.500000    0.000000          0.000000               120.000000
# 50%     55.000000    1.000000          1.000000               130.000000
# 75%     61.000000    1.000000          2.000000               140.000000
# max     77.000000    1.000000          3.000000               200.000000
#
#        Serum cholestoral  Fasting blood sugar > 120 mg/dl  \
# count         303.000000                       303.000000
# mean          246.264026                         0.148515
# std            51.830751                         0.356198
# min           126.000000                         0.000000
# ...

# %%
mydf['Age'].value_counts(sort=False)
# Out:
# 29     1
# 34     2
# 35     4
# 37     2
# 38     3
# 39     4
# 40     3
# 41    10
# 42     8
# 43     8
# 44    11
# 45     8
# 46     7
# 47     5
# 48     7
# 49     5
# 50     7
# 51    12
# 52    13
# 53     8
# 54    16
# 55     8
# 56    11
# 57    17
# 58    19
# 59    14
# 60    11
# 61     8
# 62    11
# 63     9
# 64    10
# 65     8
# 66     7
# 67     9
# 68     4
# 69     3
# 70     4
# 71     3
# 74     1
# 76     1
# 77     1
# Name: Age, dtype: int64

# %%
new_df = mydf[['Age', 'Sex', 'Maximum heart rate achieved']]
new_df.rename(columns={'Age':'Age', 'Sex':'Sex', 'Maximum heart rate achieved' : 'MaxHR'}, inplace=True)
new_df.loc[mydf['Sex'] == 1, 'Sex'] = 'Male'
new_df.loc[mydf['Sex'] == 0, 'Sex'] = 'Female'

# %%
belowOrEq40 = new_df.loc[new_df['Age'] <= 40]
between40and50 = new_df.loc[(new_df['Age'] > 40) & (new_df['Age'] <= 50)]
between50and60 = new_df.loc[(new_df['Age'] > 50) & (new_df['Age'] < 60)]
aboveOrEq60 = new_df.loc[new_df['Age'] >= 60]

# %%
belowOrEq40
# Out:
#      Age     Sex  MaxHR
# 1     37    Male    187
# 24    40    Male    178
# 44    39    Male    182
# 58    34    Male    174
# 65    35  Female    182
# 72    29    Male    202
# 115   37  Female    170
# 124   39  Female    179
# 125   34  Female    192
# 154   39  Female    152
# 157   35    Male    174
# 163   38    Male    173
# 164   38    Male    173
# 175   40    Male    114
# 212   39    Male    140
# 227   35    Male    130
# 239   35    Male    156
# 259   38    Male    182
# 283   40    Male    181

# %%
between40and50
# Out:
#      Age     Sex  MaxHR
# 2     41  Female    172
# 7     44    Male    173
# 11    48  Female    139
# 12    49    Male    171
# 15    50  Female    158
# 18    43    Male    171
# 21    44    Male    179
# 22    42    Male    178
# 30    41  Female    168
# 32    44    Male    188
# 35    46  Female    160
# 41    48    Male    180
# 42    45    Male    148
# 46    44    Male    180
# 47    47    Male    156
# 53    44  Female    175
# 56    48    Male    186
# 57    45    Male    185
# 63    41    Male    132
# 67    45  Female    175
# 68    44    Male    170
# 74    43  Female    165
# 80    41    Male    179
# 81    45    Male    170
# 84    42  Female    122
# 87    46    Male    156
# 90    48    Male    175
# 94    45  Female    138
# 98    43    Male    162
# 100   42    Male    178
# ..   ...     ...    ...
# 141   43    Male    181
# 142   42  Female    173
# 146   44  Female    149
# 148   44    Male    169
# 149   42    Male    150
# 156   47    Male    179
# ...

# %%
aboveOrEq60
# Out:
#      Age     Sex  MaxHR
# 0     63    Male    150
# 13    64    Male    144
# 17    66  Female    114
# 19    69  Female    151
# 23    61    Male    137
# 25    71  Female    162
# 28    65  Female    157
# 31    65    Male    140
# 38    65  Female    148
# 39    65  Female    151
# 51    66    Male    151
# 52    62    Male    146
# 54    63  Female    172
# 60    71  Female    130
# 69    62  Female    163
# 82    60  Female    160
# 85    67  Female    160
# 86    68    Male    151
# 96    62  Female    157
# 102   63  Female    179
# 105   68  Female    115
# 106   69    Male    131
# 110   64  Female    154
# 112   64  Female    133
# 120   64  Female    122
# 127   67  Female    172
# 129   74  Female    121
# 136   60  Female     96
# 137   62    Male    140
# 139   64    Male    105
# ..   ...     ...    ...
# 217   63    Male    132
# 218   65    Male    127
# 220   63  Female    154
# 222   65    Male    174
# 225   70    Male    125
# 226   62    Male    103
# ...

# %%
labels = ['<=40', '40-50', '50-60', '60>=']
male_means = []
female_means = []
width = 0.35

# %%
a = belowOrEq40.groupby('Sex').MaxHR.mean().astype('int')
a
# Out:
# Sex
# Female    175
# Male      167
# Name: MaxHR, dtype: int64

# %%
male_means.append(a.Male)
female_means.append(a.Female)

# %%
b = between40and50.groupby('Sex').MaxHR.mean().astype('int')
b
# Out:
# Sex
# Female    158
# Male      158
# Name: MaxHR, dtype: int64

# %%
male_means.append(b.Male)
female_means.append(b.Female)

# %%
c = between50and60.groupby('Sex').MaxHR.mean().astype('int')
c
# Out:
# Sex
# Female    150
# Male      147
# Name: MaxHR, dtype: int64

# %%
male_means.append(c.Male)
female_means.append(c.Female)

# %%
d = aboveOrEq60.groupby('Sex').MaxHR.mean().astype('int')
d
# Out:
# Sex
# Female    144
# Male      137
# Name: MaxHR, dtype: int64

# %%
male_means.append(d.Male)
female_means.append(d.Female)

# %%
x = np.arange(len(labels))

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, male_means, width, label='Male')
rects2 = ax.bar(x + width/2, female_means, width, label='Female')
ax.set_ylabel('Max Heart Rates')
ax.set_title('Scores by age group and sex')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 1),  # 1 point vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
mydf.head()
# Out:
#    Age  Sex  Chest pain type   Resting blood pressure   Serum cholestoral  \
# 0   63    1                 3                      145                233
# 1   37    1                 2                      130                250
# 2   41    0                 1                      130                204
# 3   56    1                 1                      120                236
# 4   57    0                 0                      120                354
#
#    Fasting blood sugar > 120 mg/dl  Resting electrocardiographic results  \
# 0                                1                                     0
# 1                                0                                     1
# 2                                0                                     0
# 3                                0                                     1
# 4                                0                                     1
#
#    Maximum heart rate achieved  Exercise induced angina  \
# ...

# %%
mydf.dtypes
# Out:
# Age                                                      int64
# Sex                                                      int64
# Chest pain type                                          int64
# Resting blood pressure                                   int64
# Serum cholestoral                                        int64
# Fasting blood sugar > 120 mg/dl                          int64
# Resting electrocardiographic results                     int64
# Maximum heart rate achieved                              int64
# Exercise induced angina                                  int64
# ST depression induced by exercise relative to rest     float64
# The slope of the peak exercise ST segment                int64
# Number of major vessels (0-3) colored by flourosopy      int64
# 3 = normal; 6 = fixed defect 7= reversable defect        int64
# target                                                   int64
# dtype: object

# %%
features=['Age','Resting blood pressure ','Fasting blood sugar > 120 mg/dl']

# %%
#Getting all rows and the features columns
X = mydf.loc[:, features]

# %%
X.shape
# Out:
# (303, 3)

# %%
y =mydf['Maximum heart rate achieved']

# %%
y.shape
# Out:
# (303,)

# %%
X.head()
# Out:
#    Age  Resting blood pressure   Fasting blood sugar > 120 mg/dl
# 0   63                      145                                1
# 1   37                      130                                0
# 2   41                      130                                0
# 3   56                      120                                0
# 4   57                      120                                0

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(solver='lbfgs')
print(logreg.fit(X,y))
# Out:
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
clf = tree.DecisionTreeClassifier()
clf=clf.fit(X,y)

# %%
newRecord =[[20,145,1]]
print(clf.predict(newRecord))
# Out:
# [182]

# %%
#Missing Maximum heart rate achieved column because we are predicting it
test = pd.read_csv("Data/test.csv")
Test=test.rename(columns={"age":"Age",
                         "trestbps":"Resting blood pressure ",
                         "fbs":"Fasting blood sugar > 120 mg/dl",
                         })
Test.head()
# Out:
#    Age  Resting blood pressure   Fasting blood sugar > 120 mg/dl
# 0   63                      145                                1
# 1   37                      130                                0
# 2   41                      130                                0
# 3   56                      120                                0
# 4   57                      120                                0

# %%
#X_new features for test data
X_new = Test.loc[:, features]

# %%
X_new.shape
# Out:
# (303, 3)

# %%
#Predict
new_pred_class = logreg.predict(X_new)

# %%
Test.dtypes
# Out:
# Age                                int64
# Resting blood pressure             int64
# Fasting blood sugar > 120 mg/dl    int64
# dtype: object

# %%
# to ensure the first column is Age, use .set_index
kaggle_data = pd.DataFrame({'Age':test.age,
                            'Resting blood pressure':test.trestbps,
                            'Fasting blood sugar > 120 mg/dl':test.fbs,
                            'Maximum heart rate achieved':new_pred_class}).set_index('Age')
kaggle_data.to_csv('sub.csv')

# %%
#Now we compare the original dataframe with the predicted one
mydf.head()
# Out:
#    Age  Sex  Chest pain type   Resting blood pressure   Serum cholestoral  \
# 0   63    1                 3                      145                233
# 1   37    1                 2                      130                250
# 2   41    0                 1                      130                204
# 3   56    1                 1                      120                236
# 4   57    0                 0                      120                354
#
#    Fasting blood sugar > 120 mg/dl  Resting electrocardiographic results  \
# 0                                1                                     0
# 1                                0                                     1
# 2                                0                                     0
# 3                                0                                     1
# 4                                0                                     1
#
#    Maximum heart rate achieved  Exercise induced angina  \
# ...

# %%
#Predicted Dataframe
compare = pd.read_csv("sub.csv")
compare.head()
# Out:
#    Age  Resting blood pressure  Fasting blood sugar > 120 mg/dl  \
# 0   63                     145                                1
# 1   37                     130                                0
# 2   41                     130                                0
# 3   56                     120                                0
# 4   57                     120                                0
#
#    Maximum heart rate achieved
# 0                          150
# 1                          182
# 2                          173
# 3                          160
# 4                          160
